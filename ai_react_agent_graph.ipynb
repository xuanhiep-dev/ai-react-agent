# %%
# !pip install -q langgraph==0.3.33 langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.4/47.4 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 36.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.5/216.5 kB 18.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-generativeai 0.8.5 requires google-ai-generativelanguage==0.6.15, but you have google-ai-generativelanguage 0.6.18 which is incompatible.

# %%
import os
from typing import List, Optional, Union
from pydantic import BaseModel
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langgraph.graph import StateGraph, END

# %%
# ─── LLM ───────────────────────────────────────────────────────────────────────
# Get Gemini API: https://aistudio.google.com/apikey

llm = ChatGoogleGenerativeAI(
    model="gemini-2.0-flash",
    temperature=0.0,
    # google_api_key=" ***your_api_gemini*** ",
    google_api_key="AIzaSyD0xaP2NRo410lOxbGaVG0xZwoHsf9NzAE",
    top_p=0.01,
    top_k=1,
)


# ─── STATE ─────────────────────────────────────────────────────────────────────
class AgentState(BaseModel):
    problem: str
    feedback: str = ""
    plan: Optional[List[str]] = None
    current_step: Optional[int] = None
    reasoning_memory: str = ""
    final_answer: Optional[str] = None
    next_node: str = "planning_node"
    retry_count: int = 0

# %%
planning_prompt = PromptTemplate.from_template(
    "Với vai trò là một chuyên gia toán học, bạn hãy phân tích bài toán dưới đây thành các bước giải logic, rõ ràng.\n\n"
    "Lưu ý: Không thực hiện bất kỳ phép tính nào, cũng không đưa ra đáp án cuối cùng.\n"
    "Chỉ cần trình bày tuần tự các bước lập luận cần thiết để đi đến lời giải.\n"
    "Mỗi bước cần mô tả cụ thể hành động hoặc phép biến đổi bạn sẽ tiến hành.\n"
    "Vui lòng giới hạn số bước tối đa là 3 bước.\n\n"
    "Bài toán:\n{problem}\n\n"
    "Rút kinh nghiệm từ lần lên kế hoạch và giải bị sai trước đó (nếu có):\n{feedback}\n\n"
    "Sau đây, hãy trình bày các bước lập luận dưới dạng danh sách được đánh số (từ 1 đến 3):"
)

action_prompt = PromptTemplate.from_template(
    "Là một chuyên gia toán học, bạn đang trong quá trình thực hiện giải bài toán theo nhiều bước.\n"
    "Đề bài:\n{problem}\n\n"
    "Tổng số bước trong kế hoạch: {total_steps}.\n\n"
    "Lập luận cho đến nay (các bước trước):\n{reasoning_memory}\n\n"
    "**Yêu cầu hiện tại: Chỉ thực hiện Bước {current_step}:** {current_step_description}\n\n"
    "Lưu ý: Không thực hiện bất kỳ bước nào khác, và không được bỏ qua bước này.\n"
    "Hãy cung cấp giải thích mạch lạc, chi tiết cùng các phép tính chỉ cho bước hiện tại này."
)

reflection_prompt = PromptTemplate.from_template(
    "Bài toán:\n{problem}\n\n"
    "Kế hoạch đã thực hiện:\n{plan}\n\n"
    "Dấu vết suy luận (bộ nhớ từng bước):\n{reasoning_memory}\n\n"
    "Hãy tự kiểm tra lại từng bước suy luận một cách cẩn thận (không cần trình bày quá trình tư duy này).\n\n"
    "Sau khi hoàn tất, vui lòng cung cấp phản hồi theo MỘT trong hai định dạng chính xác sau:\n\n"
    "không chính xác: <Nêu súc tích điểm chưa đúng. Chỉ rõ vấn đề nằm ở kế hoạch tổng thể hay ở một bước cụ thể (ví dụ: Bước 2), và xác định chính xác phần bị lỗi. "
    "Lưu ý: Không giải lại hay thực hiện lại bất kỳ bước nào.>\n\n"
    "chính xác: <Nêu súc tích vì sao lời giải là hợp lệ và đầy đủ. Khẳng định đáp án bằng cách kết thúc với câu: 'Đáp án đúng là ...'>\n"
)

# %%
# ─── NODES (Đã sửa đổi để in chi tiết từng bước) ─────────────────────────────────────────────────────────────────────
def planning_node(state: AgentState) -> AgentState:
    print("\n--- BẮT ĐẦU: planning_node ---")
    print(f"  Vấn đề đầu vào: {state.problem[:100]}...")
    print(f"  Phản hồi từ lần trước (nếu có): {state.feedback}")

    res = (planning_prompt | llm | StrOutputParser()).invoke(
        {"problem": state.problem, "feedback": state.feedback}
    )
    steps = [l.strip() for l in res.splitlines() if any(c.isdigit() for c in l[:3])][:3]

    print(f"  Kế hoạch mới được tạo:")
    for i, step in enumerate(steps):
        print(f"       {step}")

    new_state = state.model_copy(update=dict(plan=steps, current_step=0, next_node="acting_node", feedback=""))
    print(f"--- KẾT THÚC: planning_node ---")
    return new_state

def acting_node(state: AgentState) -> AgentState:
    print("\n--- BẮT ĐẦU: acting_node ---")
    print(f"  Vấn đề: {state.problem[:100]}...")
    print(f"  Kế hoạch hiện tại: {state.plan}")
    print(f"  Bước hiện tại: {state.current_step + 1}/{len(state.plan or [])}")
    print(f"  Bộ nhớ lý luận trước đó: {state.reasoning_memory[:200]}...")

    if state.current_step is None or state.current_step >= len(state.plan or []):
        print(f"  => Đã hoàn thành tất cả các bước hành động trong kế hoạch. Chuyển sang phản ánh.")
        new_state = state.model_copy(update={"next_node": "reflecting_node"})
        print(f"--- KẾT THÚC: acting_node ---")
        return new_state

    desc = state.plan[state.current_step]
    print(f"  Mô tả bước cần thực hiện: {desc}")

    out = (action_prompt | llm | StrOutputParser()).invoke(
        {
            "problem": state.problem,
            "plan": state.plan,
            "total_steps": len(state.plan),
            "current_step": state.current_step + 1,
            "current_step_description": desc,
            "reasoning_memory": state.reasoning_memory,
        }
    )
    print(f"  Kết quả thực hiện bước này:\n{out}")

    next_node = "reflecting_node" if state.current_step + 1 >= len(state.plan) else "acting_node"

    new_state = state.model_copy(
        update={
            "current_step": state.current_step + 1,
            "reasoning_memory": state.reasoning_memory + f"\nBước {state.current_step + 1}: {out}",
            "next_node": next_node,
        }
    )
    print(f"--- KẾT THÚC: acting_node ---")
    return new_state

def reflecting_node(state: AgentState) -> AgentState:
    print("\n--- BẮT ĐẦU: reflecting_node ---")
    print(f"  Vấn đề: {state.problem[:100]}...")
    print(f"  Kế hoạch đã thực hiện: {state.plan}")
    print(f"  Toàn bộ nhật ký lý luận: {state.reasoning_memory[:500]}...") # In một phần để tránh quá dài

    critique = (reflection_prompt | llm | StrOutputParser()).invoke(
        {
            "problem": state.problem,
            "plan": state.plan,
            "reasoning_memory": state.reasoning_memory,
        }
    ).strip()
    print(f"  Phản hồi/Phân tích từ phản ánh:\n{critique}")

    is_incorrect = critique.lower().startswith("không chính xác:")

    if is_incorrect and state.retry_count < 3:
        feedback_text = critique.partition(":")[2].strip()
        print(f"  => PHÁT HIỆN LỖI: Cần lập kế hoạch lại. Thử lại lần: {state.retry_count + 1}/3")
        new_state = state.model_copy(
            update=dict(
                feedback=feedback_text,
                plan=None,
                current_step=None,
                reasoning_memory="",
                next_node="planning_node",
                retry_count=state.retry_count + 1,
            )
        )
        print(f"--- KẾT THÚC: reflecting_node ---")
        return new_state

    print(f"\n\n  => PHẢN ÁNH HOÀN TẤT: Đã đạt được giải pháp hoặc số lần thử lại đã hết.")
    new_state = state.model_copy(update=dict(final_answer=critique, next_node="end"))
    print(f"--- KẾT THÚC: reflecting_node ---")
    return new_state

# %%
# ─── ROUTER & GRAPH (unchanged) ───────────────────────────────────────────────
def router(s: Union[AgentState, dict]) -> str:
    return s["next_node"] if isinstance(s, dict) else s.next_node


def build_graph():
    g = StateGraph(AgentState)

    g.add_node("planning_node", planning_node)
    g.add_node("acting_node", acting_node)
    g.add_node("reflecting_node", reflecting_node)
    g.add_conditional_edges("planning_node", router, {"acting_node": "acting_node"})
    g.add_conditional_edges("acting_node", router,
                            {"acting_node": "acting_node", "reflecting_node": "reflecting_node"})
    g.add_conditional_edges("reflecting_node", router,
                            {"planning_node": "planning_node", "end": END})
    g.set_entry_point("planning_node")

    compiled = g.compile()

    return compiled

# %%
# ─── DRIVER ───────────────────────────────────────────────────────────────────
def solve(problem: str):
    agent = build_graph()
    final_state = AgentState(**agent.invoke(AgentState(problem=problem)))
    print("\n--- FINAL REFLECTION ---\n")
    print(final_state.final_answer)


# ─── DEMO ──────────────────────────────────────────────────────────────────────
if __name__ == "__main__":
    solve(r"Cho hàm số $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$, với $m$ là tham số. Số cực trị của hàm số $y = |f(x) - 2017|$ là bao nhiêu?")
# Out:
# --- BẮT ĐẦU: planning_node ---
#   Vấn đề đầu vào: Cho hàm số $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$, với $m$...
#   Phản hồi từ lần trước (nếu có):
#   Kế hoạch mới được tạo:
#        1. **Xác định dạng của hàm số f(x) và tìm cực trị của f(x):** Nhận thấy $f(x)$ là hàm số bậc 4 trùng phương. Ta sẽ tìm điều kiện để $f(x)$ có bao nhiêu cực trị bằng cách xét dấu của hệ số $a$ (trong trường hợp này là $m^{2018} + 1$) và nghiệm của phương trình $f'(x) = 0$. Vì $m^{2018} + 1 > 0$ với mọi $m$, nên số cực trị của $f(x)$ phụ thuộc vào dấu của hệ số của $x^2$.
#        2. **Xác định số cực trị của hàm số g(x) = f(x) - 2017:** Hàm số $g(x) = f(x) - 2017$ là một phép tịnh tiến đồ thị của $f(x)$ xuống dưới 2017 đơn vị. Do đó, số cực trị của $g(x)$ bằng số cực trị của $f(x)$.
#        3. **Xác định số cực trị của hàm số y = |g(x)| = |f(x) - 2017|:** Hàm số $y = |g(x)|$ được tạo ra bằng cách lấy đối xứng phần đồ thị của $g(x)$ nằm dưới trục $Ox$ qua trục $Ox$. Số cực trị của $y = |g(x)|$ sẽ bằng số cực trị của $g(x)$ cộng với số nghiệm đơn (hoặc nghiệm bội lẻ) của phương trình $g(x) = 0$. Ta cần xét các trường hợp khác nhau về số nghiệm của $g(x) = 0$ dựa trên số cực trị và giá trị cực trị của $g(x)$.
# --- KẾT THÚC: planning_node ---
#
# --- BẮT ĐẦU: acting_node ---
#   Vấn đề: Cho hàm số $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$, với $m$...
#   Kế hoạch hiện tại: ["1. **Xác định dạng của hàm số f(x) và tìm cực trị của f(x):** Nhận thấy $f(x)$ là hàm số bậc 4 trùng phương. Ta sẽ tìm điều kiện để $f(x)$ có bao nhiêu cực trị bằng cách xét dấu của hệ số $a$ (trong trường hợp này là $m^{2018} + 1$) và nghiệm của phương trình $f'(x) = 0$. Vì $m^{2018} + 1 > 0$ với mọi $m$, nên số cực trị của $f(x)$ phụ thuộc vào dấu của hệ số của $x^2$.", '2. **Xác định số cực trị của hàm số g(x) = f(x) - 2017:** Hàm số $g(x) = f(x) - 2017$ là một phép tịnh tiến đồ thị của $f(x)$ xuống dưới 2017 đơn vị. Do đó, số cực trị của $g(x)$ bằng số cực trị của $f(x)$.', '3. **Xác định số cực trị của hàm số y = |g(x)| = |f(x) - 2017|:** Hàm số $y = |g(x)|$ được tạo ra bằng cách lấy đối xứng phần đồ thị của $g(x)$ nằm dưới trục $Ox$ qua trục $Ox$. Số cực trị của $y = |g(x)|$ sẽ bằng số cực trị của $g(x)$ cộng với số nghiệm đơn (hoặc nghiệm bội lẻ) của phương trình $g(x) = 0$. Ta cần xét các trường hợp khác nhau về số nghiệm của $g(x) = 0$ dựa trên số cực trị và giá trị cực trị của $g(x)$.']
#   Bước hiện tại: 1/3
#   Bộ nhớ lý luận trước đó: ...
#   Mô tả bước cần thực hiện: 1. **Xác định dạng của hàm số f(x) và tìm cực trị của f(x):** Nhận thấy $f(x)$ là hàm số bậc 4 trùng phương. Ta sẽ tìm điều kiện để $f(x)$ có bao nhiêu cực trị bằng cách xét dấu của hệ số $a$ (trong trường hợp này là $m^{2018} + 1$) và nghiệm của phương trình $f'(x) = 0$. Vì $m^{2018} + 1 > 0$ với mọi $m$, nên số cực trị của $f(x)$ phụ thuộc vào dấu của hệ số của $x^2$.
#   Kết quả thực hiện bước này:
# **Bước 1: Xác định dạng của hàm số f(x) và tìm cực trị của f(x)**
#
# Hàm số đã cho là $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$. Đây là một hàm số bậc 4 trùng phương, có dạng $f(x) = ax^4 + bx^2 + c$, với:
#
# *   $a = m^{2018} + 1$
# *   $b = -2m^{2018} - 2^{2018}m^2 - 3$
# *   $c = m^{2018} + 2018$
#
# Để tìm cực trị của $f(x)$, ta cần tìm đạo hàm $f'(x)$ và giải phương trình $f'(x) = 0$.
#
# $f'(x) = 4(m^{2018} + 1)x^3 + 2(-2m^{2018} - 2^{2018}m^2 - 3)x = 0$
#
# $f'(x) = 2x[2(m^{2018} + 1)x^2 + (-2m^{2018} - 2^{2018}m^2 - 3)] = 0$
#
# $f'(x) = 2x[2(m^{2018} + 1)x^2 - (2m^{2018} + 2^{2018}m^2 + 3)] = 0$
#
# Phương trình $f'(x) = 0$ có nghiệm $x = 0$.  Các nghiệm còn lại được xác định bởi:
#
# $2(m^{2018} + 1)x^2 - (2m^{2018} + 2^{2018}m^2 + 3) = 0$
#
# $x^2 = \frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}$
#
# Số lượng cực trị của $f(x)$ phụ thuộc vào số nghiệm thực phân biệt của phương trình $f'(x) = 0$. Vì $x=0$ luôn là một nghiệm, ta cần xét số nghiệm của phương trình $x^2 = \frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}$.
#
# Ta có $m^{2018} \ge 0$ và $m^2 \ge 0$ với mọi $m$. Do đó, $2m^{2018} + 2^{2018}m^2 + 3 > 0$ và $2(m^{2018} + 1) > 0$. Suy ra:
#
# $\frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)} > 0$
#
# Vậy, phương trình $x^2 = \frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}$ luôn có hai nghiệm phân biệt khác 0 là $x = \pm \sqrt{\frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}}$.
#
# Do đó, phương trình $f'(x) = 0$ có 3 nghiệm phân biệt: $x = 0$, $x = \sqrt{\frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}}$, và $x = -\sqrt{\frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}}$.
#
# Vì $f'(x) = 0$ có 3 nghiệm phân biệt, hàm số $f(x)$ có 3 cực trị.
# --- KẾT THÚC: acting_node ---
#
# --- BẮT ĐẦU: acting_node ---
#   Vấn đề: Cho hàm số $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$, với $m$...
#   Kế hoạch hiện tại: ["1. **Xác định dạng của hàm số f(x) và tìm cực trị của f(x):** Nhận thấy $f(x)$ là hàm số bậc 4 trùng phương. Ta sẽ tìm điều kiện để $f(x)$ có bao nhiêu cực trị bằng cách xét dấu của hệ số $a$ (trong trường hợp này là $m^{2018} + 1$) và nghiệm của phương trình $f'(x) = 0$. Vì $m^{2018} + 1 > 0$ với mọi $m$, nên số cực trị của $f(x)$ phụ thuộc vào dấu của hệ số của $x^2$.", '2. **Xác định số cực trị của hàm số g(x) = f(x) - 2017:** Hàm số $g(x) = f(x) - 2017$ là một phép tịnh tiến đồ thị của $f(x)$ xuống dưới 2017 đơn vị. Do đó, số cực trị của $g(x)$ bằng số cực trị của $f(x)$.', '3. **Xác định số cực trị của hàm số y = |g(x)| = |f(x) - 2017|:** Hàm số $y = |g(x)|$ được tạo ra bằng cách lấy đối xứng phần đồ thị của $g(x)$ nằm dưới trục $Ox$ qua trục $Ox$. Số cực trị của $y = |g(x)|$ sẽ bằng số cực trị của $g(x)$ cộng với số nghiệm đơn (hoặc nghiệm bội lẻ) của phương trình $g(x) = 0$. Ta cần xét các trường hợp khác nhau về số nghiệm của $g(x) = 0$ dựa trên số cực trị và giá trị cực trị của $g(x)$.']
#   Bước hiện tại: 2/3
#   Bộ nhớ lý luận trước đó:
# Bước 1: **Bước 1: Xác định dạng của hàm số f(x) và tìm cực trị của f(x)**
#
# Hàm số đã cho là $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$. Đây là một hàm số bậc 4 t...
#   Mô tả bước cần thực hiện: 2. **Xác định số cực trị của hàm số g(x) = f(x) - 2017:** Hàm số $g(x) = f(x) - 2017$ là một phép tịnh tiến đồ thị của $f(x)$ xuống dưới 2017 đơn vị. Do đó, số cực trị của $g(x)$ bằng số cực trị của $f(x)$.
#   Kết quả thực hiện bước này:
# **Bước 2: Xác định số cực trị của hàm số g(x) = f(x) - 2017**
#
# Ta có hàm số $g(x) = f(x) - 2017$.  Vì $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$, thì:
#
# $g(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018 - 2017$
#
# $g(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 1$
#
# Để tìm cực trị của $g(x)$, ta cần tìm đạo hàm $g'(x)$ và giải phương trình $g'(x) = 0$.
#
# $g'(x) = 4(m^{2018} + 1)x^3 + 2(-2m^{2018} - 2^{2018}m^2 - 3)x$
#
# $g'(x) = 2x[2(m^{2018} + 1)x^2 + (-2m^{2018} - 2^{2018}m^2 - 3)] = 0$
#
# $g'(x) = 2x[2(m^{2018} + 1)x^2 - (2m^{2018} + 2^{2018}m^2 + 3)] = 0$
#
# Nhận thấy rằng $g'(x) = f'(x)$.  Điều này có nghĩa là các nghiệm của $g'(x) = 0$ chính là các nghiệm của $f'(x) = 0$.
#
# Từ Bước 1, ta đã chứng minh rằng $f'(x) = 0$ có 3 nghiệm phân biệt.  Do đó, $g'(x) = 0$ cũng có 3 nghiệm phân biệt.
#
# Vì $g'(x) = 0$ có 3 nghiệm phân biệt, hàm số $g(x)$ có 3 cực trị.
#
# **Kết luận:** Hàm số $g(x) = f(x) - 2017$ có 3 cực trị.  Phép tịnh tiến đồ thị hàm số theo phương thẳng đứng không làm thay đổi số lượng cực trị.
# --- KẾT THÚC: acting_node ---
#
# --- BẮT ĐẦU: acting_node ---
#   Vấn đề: Cho hàm số $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$, với $m$...
#   Kế hoạch hiện tại: ["1. **Xác định dạng của hàm số f(x) và tìm cực trị của f(x):** Nhận thấy $f(x)$ là hàm số bậc 4 trùng phương. Ta sẽ tìm điều kiện để $f(x)$ có bao nhiêu cực trị bằng cách xét dấu của hệ số $a$ (trong trường hợp này là $m^{2018} + 1$) và nghiệm của phương trình $f'(x) = 0$. Vì $m^{2018} + 1 > 0$ với mọi $m$, nên số cực trị của $f(x)$ phụ thuộc vào dấu của hệ số của $x^2$.", '2. **Xác định số cực trị của hàm số g(x) = f(x) - 2017:** Hàm số $g(x) = f(x) - 2017$ là một phép tịnh tiến đồ thị của $f(x)$ xuống dưới 2017 đơn vị. Do đó, số cực trị của $g(x)$ bằng số cực trị của $f(x)$.', '3. **Xác định số cực trị của hàm số y = |g(x)| = |f(x) - 2017|:** Hàm số $y = |g(x)|$ được tạo ra bằng cách lấy đối xứng phần đồ thị của $g(x)$ nằm dưới trục $Ox$ qua trục $Ox$. Số cực trị của $y = |g(x)|$ sẽ bằng số cực trị của $g(x)$ cộng với số nghiệm đơn (hoặc nghiệm bội lẻ) của phương trình $g(x) = 0$. Ta cần xét các trường hợp khác nhau về số nghiệm của $g(x) = 0$ dựa trên số cực trị và giá trị cực trị của $g(x)$.']
#   Bước hiện tại: 3/3
#   Bộ nhớ lý luận trước đó:
# Bước 1: **Bước 1: Xác định dạng của hàm số f(x) và tìm cực trị của f(x)**
#
# Hàm số đã cho là $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$. Đây là một hàm số bậc 4 t...
#   Mô tả bước cần thực hiện: 3. **Xác định số cực trị của hàm số y = |g(x)| = |f(x) - 2017|:** Hàm số $y = |g(x)|$ được tạo ra bằng cách lấy đối xứng phần đồ thị của $g(x)$ nằm dưới trục $Ox$ qua trục $Ox$. Số cực trị của $y = |g(x)|$ sẽ bằng số cực trị của $g(x)$ cộng với số nghiệm đơn (hoặc nghiệm bội lẻ) của phương trình $g(x) = 0$. Ta cần xét các trường hợp khác nhau về số nghiệm của $g(x) = 0$ dựa trên số cực trị và giá trị cực trị của $g(x)$.
#   Kết quả thực hiện bước này:
# **Bước 3: Xác định số cực trị của hàm số y = |g(x)| = |f(x) - 2017|**
#
# Như đã kết luận ở Bước 2, hàm số $g(x) = f(x) - 2017$ có 3 cực trị. Hàm số $g(x)$ có dạng $ax^4 + bx^2 + c$ với $a = m^{2018} + 1 > 0$, do đó đồ thị của $g(x)$ có dạng chữ "W".  Ta biết $g(x)$ có 3 cực trị, trong đó có một cực đại tại $x=0$ và hai cực tiểu đối xứng nhau qua trục tung.
#
# Để xác định số cực trị của $y = |g(x)|$, ta cần xét số nghiệm của phương trình $g(x) = 0$. Số cực trị của $y = |g(x)|$ bằng số cực trị của $g(x)$ cộng với số nghiệm đơn (hoặc nghiệm bội lẻ) của phương trình $g(x) = 0$.
#
# Ta có $g(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 1$.
# Đặt $t = x^2$, ta có phương trình $(m^{2018} + 1)t^2 + (-2m^{2018} - 2^{2018}m^2 - 3)t + m^{2018} + 1 = 0$.
# Gọi $t_1, t_2$ là hai nghiệm của phương trình bậc hai này. Khi đó, số nghiệm của $g(x) = 0$ phụ thuộc vào dấu của $t_1, t_2$.
#
# *   **Trường hợp 1: $g(0) = m^{2018} + 1 > 0$**.  Vì $g(x)$ có dạng chữ "W" và $g(0) > 0$, ta cần xét giá trị cực tiểu của $g(x)$.  Gọi $x_0$ là một trong hai điểm cực tiểu (khác 0) của $g(x)$. Khi đó $g(x_0)$ là giá trị cực tiểu.
#
#     *   Nếu $g(x_0) > 0$, thì $g(x) > 0$ với mọi $x$, do đó $g(x) = 0$ vô nghiệm.  Khi đó, $|g(x)| = g(x)$, và số cực trị của $|g(x)|$ bằng số cực trị của $g(x)$, tức là 3.
#     *   Nếu $g(x_0) = 0$, thì $g(x) = 0$ có 2 nghiệm (bội chẵn). Khi đó, số cực trị của $|g(x)|$ là 3 (cực trị của g(x)) + 0 (số nghiệm đơn) = 3.
#     *   Nếu $g(x_0) < 0$, thì $g(x) = 0$ có 4 nghiệm phân biệt. Khi đó, số cực trị của $|g(x)|$ là 3 (cực trị của g(x)) + 4 (số nghiệm đơn) = 7.
#
# Để xác định dấu của $g(x_0)$, ta cần tìm $x_0$. Ta biết $x_0^2 = \frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}$.
# Khi đó, $g(x_0) = (m^{2018} + 1)x_0^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x_0^2 + m^{2018} + 1$.
# Thay $x_0^2 = \frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}$ vào, ta được:
# $g(x_0) = (m^{2018} + 1) (\frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)})^2 + (-2m^{2018} - 2^{2018}m^2 - 3)(\frac{2m^{2018} + 2^{2018}m^2 + 3}{2(m^{2018} + 1)}) + m^{2018} + 1$
# $g(x_0) = \frac{(2m^{2018} + 2^{2018}m^2 + 3)^2}{4(m^{2018} + 1)} - \frac{(2m^{2018} + 2^{2018}m^2 + 3)^2}{2(m^{2018} + 1)} + m^{2018} + 1$
# $g(x_0) = -\frac{(2m^{2018} + 2^{2018}m^2 + 3)^2}{4(m^{2018} + 1)} + m^{2018} + 1$
# $g(x_0) = \frac{4(m^{2018} + 1)^2 - (2m^{2018} + 2^{2018}m^2 + 3)^2}{4(m^{2018} + 1)}$
# $g(x_0) = \frac{[2(m^{2018} + 1) - (2m^{2018} + 2^{2018}m^2 + 3)][2(m^{2018} + 1) + (2m^{2018} + 2^{2018}m^2 + 3)]}{4(m^{2018} + 1)}$
# $g(x_0) = \frac{(-2^{2018}m^2 - 1)(4m^{2018} + 2^{2018}m^2 + 5)}{4(m^{2018} + 1)}$
#
# Vì $m^{2018} \ge 0$ và $m^2 \ge 0$, ta có $-2^{2018}m^2 - 1 < 0$ và $4m^{2018} + 2^{2018}m^2 + 5 > 0$. Do đó, $g(x_0) < 0$.
#
# Vậy, $g(x) = 0$ có 4 nghiệm phân biệt. Do đó, số cực trị của $|g(x)|$ là 3 + 4 = 7.
#
# **Kết luận:** Số cực trị của hàm số $y = |f(x) - 2017|$ là 7.
# --- KẾT THÚC: acting_node ---
#
# --- BẮT ĐẦU: reflecting_node ---
#   Vấn đề: Cho hàm số $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$, với $m$...
#   Kế hoạch đã thực hiện: ["1. **Xác định dạng của hàm số f(x) và tìm cực trị của f(x):** Nhận thấy $f(x)$ là hàm số bậc 4 trùng phương. Ta sẽ tìm điều kiện để $f(x)$ có bao nhiêu cực trị bằng cách xét dấu của hệ số $a$ (trong trường hợp này là $m^{2018} + 1$) và nghiệm của phương trình $f'(x) = 0$. Vì $m^{2018} + 1 > 0$ với mọi $m$, nên số cực trị của $f(x)$ phụ thuộc vào dấu của hệ số của $x^2$.", '2. **Xác định số cực trị của hàm số g(x) = f(x) - 2017:** Hàm số $g(x) = f(x) - 2017$ là một phép tịnh tiến đồ thị của $f(x)$ xuống dưới 2017 đơn vị. Do đó, số cực trị của $g(x)$ bằng số cực trị của $f(x)$.', '3. **Xác định số cực trị của hàm số y = |g(x)| = |f(x) - 2017|:** Hàm số $y = |g(x)|$ được tạo ra bằng cách lấy đối xứng phần đồ thị của $g(x)$ nằm dưới trục $Ox$ qua trục $Ox$. Số cực trị của $y = |g(x)|$ sẽ bằng số cực trị của $g(x)$ cộng với số nghiệm đơn (hoặc nghiệm bội lẻ) của phương trình $g(x) = 0$. Ta cần xét các trường hợp khác nhau về số nghiệm của $g(x) = 0$ dựa trên số cực trị và giá trị cực trị của $g(x)$.']
#   Toàn bộ nhật ký lý luận:
# Bước 1: **Bước 1: Xác định dạng của hàm số f(x) và tìm cực trị của f(x)**
#
# Hàm số đã cho là $f(x) = (m^{2018} + 1)x^4 + (-2m^{2018} - 2^{2018}m^2 - 3)x^2 + m^{2018} + 2018$. Đây là một hàm số bậc 4 trùng phương, có dạng $f(x) = ax^4 + bx^2 + c$, với:
#
# *   $a = m^{2018} + 1$
# *   $b = -2m^{2018} - 2^{2018}m^2 - 3$
# *   $c = m^{2018} + 2018$
#
# Để tìm cực trị của $f(x)$, ta cần tìm đạo hàm $f'(x)$ và giải phương trình $f'(x) = 0$.
#
# $f'(x) = 4(m^{2018} + 1)x^3 + 2(-2m^{2018} - 2^{2018}m^2 - 3)x = 0$
#
# ...
#   Phản hồi/Phân tích từ phản ánh:
# chính xác: <Lời giải hợp lệ và đầy đủ. Các bước suy luận logic và chặt chẽ, dẫn đến kết quả đúng. Việc xác định số nghiệm của g(x) = 0 và từ đó suy ra số cực trị của |g(x)| được thực hiện chính xác. Đáp án đúng là 7>
#
#
#   => PHẢN ÁNH HOÀN TẤT: Đã đạt được giải pháp hoặc số lần thử lại đã hết.
# --- KẾT THÚC: reflecting_node ---
#
# --- FINAL REFLECTION ---
#
# chính xác: <Lời giải hợp lệ và đầy đủ. Các bước suy luận logic và chặt chẽ, dẫn đến kết quả đúng. Việc xác định số nghiệm của g(x) = 0 và từ đó suy ra số cực trị của |g(x)| được thực hiện chính xác. Đáp án đúng là 7>
